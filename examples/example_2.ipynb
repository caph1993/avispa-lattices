# %%
import avispa_lattices as AL
import avispa_lattices.base_methods
print(AL)
import numpy as np

np.random.seed(0)

L = AL.generation.random_lattice_czech(5)
L.show()

f = AL.generation.random_f_preserving_lub(L)
g = AL.generation.random_f_preserving_lub(L)
L.show(f)
L.show(g)

h = AL.endomorphisms.f_glb_pointwise(L, f, g)
L.show(h)
# Out:
# <module 'avispa_lattices' from '/mnt/data/documents/Avispa/avispa-lattices/examples/../avispa_lattices/__init__.py'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2002267a976b> in <module>
#      16 L.show(g)
#      17
# ---> 18 h = AL.endomorphisms.f_glb_pointwise(L, f, g)
#      19 L.show(h)
#
# TypeError: f_glb_pointwise() takes 2 positional arguments but 3 were given
